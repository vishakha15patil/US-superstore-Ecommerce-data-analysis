# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:/python/resume project/SampleSuperstoreSales.csv")

# %%
df.head()
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity       Sales  \
# 0       1         3   10-13-10            Low               6    261.5400
# 1      49       293   10-01-12           High              49  10123.0200
# 2      50       293   10-01-12           High              27    244.5700
# 3      80       483   07-10-11           High              30   4965.7595
# 4      85       515   08-28-10  Not Specified              19    394.2700
#
#    Discount       Ship Mode   Profit  Unit Price  ...       Customer Name  \
# 0      0.04     Regular Air  -213.25       38.94  ...  Muhammed MacIntyre
# 1      0.07  Delivery Truck   457.81      208.16  ...        Barry French
# 2      0.01     Regular Air    46.71        8.69  ...        Barry French
# 3      0.08     Regular Air  1198.97      195.99  ...       Clay Rozendal
# 4      0.08     Regular Air    30.94       21.78  ...      Carlos Soltero
#
#   Province   Region Customer Segment Product Category  \
# ...

# %%
df.shape
# Out:
# (8399, 21)

# %%
df.isnull().sum()
# Out:
# Row ID                  0
# Order ID                0
# Order Date              0
# Order Priority          0
# Order Quantity          0
# Sales                   0
# Discount                0
# Ship Mode               0
# Profit                  0
# Unit Price              0
# Shipping Cost           0
# Customer Name           0
# Province                0
# Region                  0
# Customer Segment        0
# Product Category        0
# Product Sub-Category    0
# Product Name            0
# Product Container       0
# Product Base Margin     0
# Ship Date               0
# dtype: int64

# %%
df['Product Base Margin'].fillna(df['Product Base Margin'].mean(),inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_2720\3821109820.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Product Base Margin'].fillna(df['Product Base Margin'].mean(),inplace=True)

# %%
df['Order Priority'].value_counts()
# Out:
# Order Priority
# High             1768
# Low              1720
# Not Specified    1672
# Medium           1631
# Critical         1608
# Name: count, dtype: int64

# %%
df['Order Priority'].unique()
# Out:
# array(['Low', 'High', 'Not Specified', 'Medium', 'Critical'], dtype=object)

# %%
plt.figure(figsize=(6,3))
sns.countplot(x='Order Priority',data=df)
plt.title('count of Order Priority')
plt.savefig('count of Order Priority.jpg')
plt.show()

# %% [markdown]
# #ship mode

# %%
df['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Regular Air       6270
# Delivery Truck    1146
# Express Air        983
# Name: count, dtype: int64

# %%
x=df['Ship Mode'].value_counts().index
y=df['Ship Mode'].value_counts().values

# %%
x
# Out:
# Index(['Regular Air', 'Delivery Truck', 'Express Air'], dtype='object', name='Ship Mode')

# %%
y
# Out:
# array([6270, 1146,  983], dtype=int64)

# %%
plt.figure(figsize=(5,3))
plt.pie(y, labels=x,startangle=60, autopct="%1.2f%%")
plt.title("Percentage of Shipping Mode")
plt.savefig('Percentage of Shipping Mode.jpg')
plt.legend(loc=3)
plt.show()

# %%
plt.figure(figsize=(5,3))
sns.countplot(x='Ship Mode',data=df, hue='Product Category')
plt.title("Order Distribution by Category and Shipping Mode")
plt.savefig('Order Distribution by Category and Shipping Mode.jpg')
plt.show()

# %% [markdown]
# #Customer Segment

# %%
plt.figure(figsize=(5,3))
sns.countplot(x='Customer Segment',data=df)
plt.title("Count of customer segment")
plt.savefig('count of customer segment.jpg')
plt.show()

# %% [markdown]
# #Product Category

# %%
plt.figure(figsize=(5,3))
sns.countplot(x='Product Category',data=df)
plt.title("Count of Product Category")
plt.savefig('count of Product Category.jpg')
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.countplot(x='Product Category',data=df[df['Product Category']=="Office Supplies"] , hue="Product Sub-Category")
plt.title("Plot of Product Sub-Category in Office Supplies")
plt.savefig("Plot of Product Sub-Category in Office Supplies.jpg")
plt.show()

# %%
plt.figure(figsize=(6,3))
sns.countplot(x='Product Category',data=df[df['Product Category']=="Technology"] , hue="Product Sub-Category")
plt.title("Plot of Product Sub-Category in Technology")
plt.savefig("Plot of Product Sub-Category in Technology.jpg")
plt.show()

# %%
plt.figure(figsize=(6,3))
sns.countplot(x='Product Category',data=df[df['Product Category']=="Furniture"] , hue="Product Sub-Category")
plt.title("Plot of Product Sub-Category in Furniture")
plt.savefig("Plot of Product Sub-Category in Furniture.jpg")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8399 entries, 0 to 8398
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                8399 non-null   int64
#  1   Order ID              8399 non-null   int64
#  2   Order Date            8399 non-null   datetime64[ns]
#  3   Order Priority        8399 non-null   object
#  4   Order Quantity        8399 non-null   int64
#  5   Sales                 8399 non-null   float64
#  6   Discount              8399 non-null   float64
#  7   Ship Mode             8399 non-null   object
#  8   Profit                8399 non-null   float64
#  9   Unit Price            8399 non-null   float64
#  10  Shipping Cost         8399 non-null   float64
#  11  Customer Name         8399 non-null   object
#  12  Province              8399 non-null   object
#  13  Region                8399 non-null   object
# ...

# %%
date_type = df[['Order Date', 'Ship Date']]
date_type.head()
# Out:
#   Order Date Ship Date
# 0   10-13-10  10-20-10
# 1   10-01-12  10-02-12
# 2   10-01-12  10-03-12
# 3   07-10-11  07-12-11
# 4   08-28-10  08-30-10

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], format='mixed', errors='coerce')
df['Ship Date'] = pd.to_datetime(df['Ship Date'], format='mixed', errors='coerce')

# Verify the conversion
print(df[['Order Date', 'Ship Date']].dtypes)
# Out:
# Order Date    datetime64[ns]
# Ship Date     datetime64[ns]
# dtype: object

# %%
df['Order year']=df['Order Date'].dt.year

# %%
df['Order year'].value_counts()
# Out:
# Order year
# 2009    2153
# 2010    2142
# 2012    2102
# 2011    2002
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,3))
sns.countplot(x='Order year',data=df)
plt.title("Order placed by year")
plt.savefig("Order placed by year.jpg")
plt.show()

# %% [markdown]
# profit

# %%
sns.barplot(x='Product Category', y='Profit',data=df, estimator='sum')
plt.title("Product Category wise Profit")
plt.savefig("Product Category wise Profit.jpg")
plt.show()

# %%
df['Province'].value_counts()[:5]
# Out:
# Province
# Ontario             1826
# British Columbia    1126
# Saskachewan          913
# Alberta              865
# Manitoba             793
# Name: count, dtype: int64

# %%
df['Product Container'].value_counts()
# Out:
# Product Container
# Small Box     4347
# Wrap Bag      1168
# Small Pack     956
# Jumbo Drum     624
# Jumbo Box      532
# Large Box      406
# Medium Box     366
# Name: count, dtype: int64

# %%
sns.barplot(x='Product Category', y='Product Base Margin',data=df, estimator='sum')
plt.title("Product Category wise Product Base Margin")
plt.savefig("Product Category wise Product Base Margin.jpg")
plt.show()

# %%
CONCLUSION:
